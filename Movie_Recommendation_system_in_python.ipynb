# %%
import pandas as pd
import numpy as np

# %%
# https://grouplens.org/datasets/movielens/latest/
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
movie_titles = pd.read_csv("Movie_Id_Titles.csv")
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %% [markdown]
# We merge both dataset through item_id coloumn.

# %%
df_merge=pd.merge(df,movie_titles,on='item_id')
df_merge.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %% [markdown]
# **EDA**

# %% [markdown]
# Visualization Import

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
df_merge.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# They Made Me a Criminal (1939)                5.0
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Saint of Fort Washington, The (1993)          5.0
# Someone Else's America (1995)                 5.0
# Star Kid (1997)                               5.0
# Name: rating, dtype: float64

# %% [markdown]
# **Visualize through user perspective**

# %%
df_merge.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df_merge.groupby('title')['rating'].mean())
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings['num of ratings'] = pd.DataFrame(df_merge.groupby('title')['rating'].count())
ratings.head()
# Out:
#                              rating  num of ratings
# title
# 'Til There Was You (1997)  2.333333               9
# 1-900 (1994)               2.600000               5
# 101 Dalmatians (1996)      2.908257             109
# 12 Angry Men (1957)        4.344000             125
# 187 (1997)                 3.024390              41

# %% [markdown]
# Few  Histrogram

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)
# Out:
# <Axes: >

# %% [markdown]
# **Recommending Similar Movies**

# %% [markdown]
# **Pivot Table**

# %%
movie_table=df_merge.pivot_table(index='user_id',columns='title',values='rating')
movie_table.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                                  rating  num of ratings
# title
# Star Wars (1977)               4.359589             584
# Contact (1997)                 3.803536             509
# Fargo (1996)                   4.155512             508
# Return of the Jedi (1983)      4.007890             507
# Liar Liar (1997)               3.156701             485
# English Patient, The (1996)    3.656965             481
# Scream (1996)                  3.441423             478
# Toy Story (1995)               3.878319             452
# Air Force One (1997)           3.631090             431
# Independence Day (ID4) (1996)  3.438228             429

# %%
ratings.head()
# Out:
#                              rating  num of ratings
# title
# 'Til There Was You (1997)  2.333333               9
# 1-900 (1994)               2.600000               5
# 101 Dalmatians (1996)      2.908257             109
# 12 Angry Men (1957)        4.344000             125
# 187 (1997)                 3.024390              41

# %% [markdown]
# Now let's grab the user ratings for those two movies:

# %%
starwars_user_ratings = movie_table['Star Wars (1977)']
liarliar_user_ratings = movie_table['Liar Liar (1997)']
starwars_user_ratings.head()
# Out:
# user_id
# 0    5.0
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# Name: Star Wars (1977), dtype: float64

# %% [markdown]
# We can then use corrwith() method to get correlations between two pandas series:

# %%
similar_to_starwars=-movie_table.corrwith(starwars_user_ratings)
similar_to_liarliar=-movie_table.corrwith(liarliar_user_ratings)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                            Correlation
# title
# 'Til There Was You (1997)    -0.872872
# 1-900 (1994)                  0.645497
# 101 Dalmatians (1996)        -0.211132
# 12 Angry Men (1957)          -0.184289
# 187 (1997)                   -0.027398

# %% [markdown]
# Now if we sort the dataframe by correlation, we should get the most similar movies, however note that we get some results that don't really make sense. This is because there are a lot of movies only watched once by users who also watched star wars (it was the most popular movie).

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                         Correlation
# title
# Crossfire (1947)                                1.0
# Love and Death on Long Island (1997)            1.0
# Fille seule, La (A Single Girl) (1995)          1.0
# For Ever Mozart (1996)                          1.0
# Frankie Starlight (1995)                        1.0
# Swept from the Sea (1997)                       1.0
# Theodore Rex (1995)                             1.0
# I Like It Like That (1994)                      1.0
# Two Deaths (1995)                               1.0
# American Dream (1990)                           1.0

# %% [markdown]
# Let's fix this by filtering out movies that have less than 100 reviews (this value was chosen based off the histogram from earlier)

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                            Correlation  num of ratings
# title
# 'Til There Was You (1997)    -0.872872               9
# 1-900 (1994)                  0.645497               5
# 101 Dalmatians (1996)        -0.211132             109
# 12 Angry Men (1957)          -0.184289             125
# 187 (1997)                   -0.027398              41

# %% [markdown]
# "Movie recommended based on Star Wars (1977)."

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                               Correlation  num of ratings
# title
# First Wives Club, The (1996)     0.194496             160
# G.I. Jane (1997)                 0.176734             175
# Crash (1996)                     0.148507             128
# As Good As It Gets (1997)        0.130466             112
# Edge, The (1997)                 0.127167             113

# %% [markdown]
# "Movie recommended based on Liar Liar (1997."

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                                     Correlation  \
# title
# Raging Bull (1980)                                     0.308129
# Welcome to the Dollhouse (1995)                        0.254231
# Dr. Strangelove or: How I Learned to Stop Worry...     0.238092
# Ed Wood (1994)                                         0.199481
# Hoop Dreams (1994)                                     0.184503
#
#                                                     num of ratings
# title
# Raging Bull (1980)                                             116
# Welcome to the Dollhouse (1995)                                112
# Dr. Strangelove or: How I Learned to Stop Worry...             194
# Ed Wood (1994)                                                 133
# Hoop Dreams (1994)                                             117
